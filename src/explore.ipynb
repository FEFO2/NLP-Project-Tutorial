# %% [markdown]
# # Explore here

# %% [markdown]
# ### 1.0. Libraries and dataset

# %%
#LIBRARIES
import pandas as pd

total_data = pd.read_csv('https://raw.githubusercontent.com/4GeeksAcademy/NLP-project-tutorial/main/url_spam.csv')
total_data.info
# Out:
# <bound method DataFrame.info of                                                     url  is_spam
# 0     https://briefingday.us8.list-manage.com/unsubs...     True
# 1                                https://www.hvper.com/     True
# 2                    https://briefingday.com/m/v4n3i4f3     True
# 3      https://briefingday.com/n/20200618/m#commentform    False
# 4                           https://briefingday.com/fan     True
# ...                                                 ...      ...
# 2994  https://www.smartcitiesworld.net/news/news/dee...    False
# 2995                      https://www.youtube.com/watch     True
# 2996  https://techcrunch.com/2019/07/04/an-optimisti...    False
# 2997  https://www.technologyreview.com/2019/12/20/13...    False
# 2998       https://www.bbc.com/news/technology-51018758    False
#
# [2999 rows x 2 columns]>

# %% [markdown]
# ### 1.1. data processing

# %%
import re
example = 'https://www.hvper.com/'
partes = re.split(r'\.|/',example)
partes = [partes for partes in partes if partes != '']
partes
# Out:
# ['https:', 'www', 'hvper', 'com']

# %%
import re

# Cadena de ejemplo
# cadena = "Hola,mundo!Este,es,un,ejemplo"
# partes = re.split(r',|!', cadena)


for x in total_data['url']:
    x = re.split(r'.|/',x)
    print(x)
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ...

# %%
import re
from string import punctuation
URL  = 'https://www.hvper.com/'

result = re.sub(string.punctuation)

# %%
import re
import string.punctuation 
def clean_url(url):
    # Eliminar el protocolo (http, https) y el prefijo www
    cleaned_url = re.sub(r'https?://(www\.)?', '', url)

    # Eliminar barras al final de la URL
    cleaned_url = re.sub(r'/$', '', cleaned_url)

    return cleaned_url

# Ejemplo de uso
url_original = "https://www.hvper.com/ejemplo/ruta/"
url_limpia = limpiar_url(url_original)

print("URL original:", url_original)
print("URL limpia:", url_limpia)
# Out:
# URL original: https://www.hvper.com/ejemplo/ruta/
# URL limpia: hvper.com/ejemplo/ruta
